# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings
# Out:
# <function warnings.filterwarnings(action, message='', category=<class 'Warning'>, module='', lineno=0, append=False)>

# %%
df = pd.read_csv('G:/ML Projects/Credit card fraud detection/creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.title('Value Counts of Class')
sns.countplot(data=df,x='Class')
# Out:
# <AxesSubplot:title={'center':'Value Counts of Class'}, xlabel='Class', ylabel='count'>

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.title('Correlation Plot')
sns.heatmap(data=round(df.corr(),2),annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation Plot'}>

# %%
df.corr()[['Class']].sort_values('Class')[:-1]
# Out:
#            Class
# V17    -0.326481
# V14    -0.302544
# V12    -0.260593
# V10    -0.216883
# V16    -0.196539
# V3     -0.192961
# V7     -0.187257
# V18    -0.111485
# V1     -0.101347
# V9     -0.097733
# V5     -0.094974
# V6     -0.043643
# Time   -0.012323
# V24    -0.007221
# V13    -0.004570
# V15    -0.004223
# V23    -0.002685
# V22     0.000805
# V25     0.003308
# V26     0.004455
# Amount  0.005632
# V28     0.009536
# V27     0.017580
# V8      0.019875
# V20     0.020090
# V19     0.034783
# V21     0.040413
# V2      0.091289
# V4      0.133447
# V11     0.154876

# %%
plt.figure(figsize=(20,10))
plt.title('V17 & V14 vs Class')
sns.scatterplot(data=df,x ='V17',y = 'V14', hue = 'Class')
# Out:
# <AxesSubplot:title={'center':'V17 & V14 vs Class'}, xlabel='V17', ylabel='V14'>

# %%
plt.figure(figsize=(20,10))
plt.title('V12 & V10 vs Class')
sns.scatterplot(data = df, x= 'V12',y ='V10', hue ='Class')
# Out:
# <AxesSubplot:title={'center':'V12 & V10 vs Class'}, xlabel='V12', ylabel='V10'>

# %%
# Modelling
x = df.drop('Class',axis = 1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3,random_state = 42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier, XGBRFClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# %%
from warnings import filterwarnings
from sklearn.metrics import classification_report
filterwarnings('ignore')

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.20, random_state=42)

# %%
LogisticRegression_model = LogisticRegression()
LogisticRegression_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
LogisticRegression_model.score(X_train, y_train)
# Out:
# 0.9989817639184533

# %%
LogisticRegression_model.score(X_test, y_test)
# Out:
# 0.9986306660580738

# %%
KNeighborsClassifier_model = KNeighborsClassifier()
KNeighborsClassifier_model.fit(X_train, y_train)
print(KNeighborsClassifier_model.score(X_train, y_train))
print(KNeighborsClassifier_model.score(X_test, y_test))

# %%
SVC_model = SVC()
SVC_model.fit(X_train, y_train)
print(SVC_model.score(X_train, y_train))
print(SVC_model.score(X_test, y_test))
# Out:
# 0.9982707542408216
# 0.9982795547909132

# %%
DecisionTreeClassifier_model = DecisionTreeClassifier()
DecisionTreeClassifier_model.fit(X_train, y_train)
print(DecisionTreeClassifier_model.score(X_train, y_train))
print(DecisionTreeClassifier_model.score(X_test, y_test))
# Out:
# 1.0
# 0.9991222218320986

# %%
RandomForestClassifier_model = RandomForestClassifier()
RandomForestClassifier_model.fit(X_train, y_train)
print(RandomForestClassifier_model.score(X_train, y_train))
print(RandomForestClassifier_model.score(X_test, y_test))

# %%
AdaBoostClassifier_model = AdaBoostClassifier()
AdaBoostClassifier_model.fit(X_train, y_train)
print(AdaBoostClassifier_model.score(X_train, y_train))
print(AdaBoostClassifier_model.score(X_test, y_test))

# %%
GradientBoostingClassifier_model = GradientBoostingClassifier()
GradientBoostingClassifier_model.fit(X_train, y_train)
print(GradientBoostingClassifier_model.score(X_train, y_train))
print(GradientBoostingClassifier_model.score(X_test, y_test))

# %%
XGBClassifier_model = XGBClassifier()
XGBClassifier_model.fit(X_train, y_train)
print(XGBClassifier_model.score(X_train, y_train))
print(XGBClassifier_model.score(X_test, y_test))

# %%
XGBRFClassifier_model = XGBRFClassifier()
XGBRFClassifier_model.fit(X_train, y_train)
print(XGBRFClassifier_model.score(X_train, y_train))
print(XGBRFClassifier_model.score(X_test, y_test))

# %%
CatBoostClassifier_model = CatBoostClassifier()
CatBoostClassifier_model.fit(X_train, y_train)
print(CatBoostClassifier.score(X_train, y_train))
print(CatBoostClassifier.score(X_test, y_test))

# %%
LGBMClassifier_model = LGBMClassifier()
LGBMClassifier_model.fit(X_train, y_train)
print(LGBMClassifier_model.score(X_train, y_train))
print(LGBMClassifier_model.score(X_test, y_test))
